# %%
import pandas as pd
import datetime
from datetime import datetime as dt
import sys
sys.path.append(r'C:/Users/waliy/Data Onlimo/MA_Onlimo/Pages')
from KLHK_41 import tanggal_data
#import KLHK_42 as K42
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\Anaconda3\envs\env1\lib\site-packages\streamlit\legacy_caching\hashing.py:368, in _CodeHasher.to_bytes(self, obj, context)
#     366 try:
#     367     # Hash the input
# --> 368     b = b"%s:%s" % (tname, self._to_bytes(obj, context))
#     370     # Hmmm... It's possible that the size calculation is wrong. When we
#     371     # call to_bytes inside _to_bytes things get double-counted.
#
# File ~\Anaconda3\envs\env1\lib\site-packages\streamlit\legacy_caching\hashing.py:634, in _CodeHasher._to_bytes(self, obj, context)
#     633 assert code is not None
# --> 634 if self._file_should_be_hashed(code.co_filename):
#     635     context = _get_context(obj)
#
# File ~\Anaconda3\envs\env1\lib\site-packages\streamlit\legacy_caching\hashing.py:410, in _CodeHasher._file_should_be_hashed(self, filename)
#     408     return False
# ...

# %%
tanggal_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 tanggal_data
#
# NameError: name 'tanggal_data' is not defined
